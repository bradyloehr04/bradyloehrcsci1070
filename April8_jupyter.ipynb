# %%
import numpy as np
import sklearn as sk
import os
import math
import statistics
from scipy import stats
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import r2_score
import pandas as pd
import requests
from io import StringIO
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from statsmodels.formula.api import logit
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler 
from imblearn.under_sampling import ClusterCentroids
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from xgboost import XGBClassifier
from sklearn.tree import plot_tree
from scipy.spatial.distance import cdist
from sklearn.cluster import KMeans

# %%
crime_df=pd.read_csv('USArrests.csv')

# %%
crime_df
# Out:
#              State  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# 12        Illinois    10.4      249        83  24.0
# 13         Indiana     7.2      113        65  21.0
# 14            Iowa     2.2       56        57  11.3
# 15          Kansas     6.0      115        66  18.0
# 16        Kentucky     9.7      109        52  16.3
# 17       Louisiana    15.4      249        66  22.2
# 18           Maine     2.1       83        51   7.8
# 19        Maryland    11.3      300        67  27.8
# 20   Massachusetts     4.4      149        85  16.3
# 21        Michigan    12.1      255        74  35.1
# 22       Minnesota     2.7       72        66  14.9
# 23     Mississippi    16.1      259        44  17.1
# 24        Missouri     9.0      178        70  28.2
# 25         Montana     6.0      109        53  16.4
# 26        Nebraska     4.3      102        62  16.5
# 27          Nevada    12.2      252        81  46.0
# 28   New Hampshire     2.1       57        56   9.5
# 29      New Jersey     7.4      159        89  18.8
# 30      New Mexico    11.4      285        70  32.1
# 31        New York    11.1      254        86  26.1
# 32  North Carolina    13.0      337        45  16.1
# 33    North Dakota     0.8       45        44   7.3
# 34            Ohio     7.3      120        75  21.4
# 35        Oklahoma     6.6      151        68  20.0
# 36          Oregon     4.9      159        67  29.3
# 37    Pennsylvania     6.3      106        72  14.9
# 38    Rhode Island     3.4      174        87   8.3
# 39  South Carolina    14.4      279        48  22.5
# 40    South Dakota     3.8       86        45  12.8
# 41       Tennessee    13.2      188        59  26.9
# 42           Texas    12.7      201        80  25.5
# 43            Utah     3.2      120        80  22.9
# 44         Vermont     2.2       48        32  11.2
# 45        Virginia     8.5      156        63  20.7
# 46      Washington     4.0      145        73  26.2
# 47   West Virginia     5.7       81        39   9.3
# 48       Wisconsin     2.6       53        66  10.8
# 49         Wyoming     6.8      161        60  15.6

# %%
X=crime_df.drop('State', axis=1)
y=crime_df['State']
plt.scatter(X['Murder'],X['UrbanPop'])
for i, txt in enumerate(y):
    plt.annotate(txt, X['Murder'][i],X['UrbanPop'][i])

plt.xlabel('Murder')
plt.ylabel('UrbanPop')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       3 plt.scatter(X['Murder'],X['UrbanPop'])
#       4 for i, txt in enumerate(y):
# ----> 5     plt.annotate(txt, X['Murder'][i],X['UrbanPop'][i])
#       7 plt.xlabel('Murder')
#       8 plt.ylabel('UrbanPop')
#
# File c:\users\brady\appdata\local\programs\python\python39\lib\site-packages\matplotlib\pyplot.py:2647, in annotate(text, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#    2627 @_copy_docstring_and_deprecators(Axes.annotate)
#    2628 def annotate(
#    2629     text: str,
#    (...)
#    2645     **kwargs,
#    2646 ) -> Annotation:
# -> 2647     return gca().annotate(
#    2648         text,
#    2649         xy,
#    2650         xytext=xytext,
#    2651         xycoords=xycoords,
#    2652         textcoords=textcoords,
#    2653         arrowprops=arrowprops,
#    2654         annotation_clip=annotation_clip,
#    2655         **kwargs,
#    2656     )
#
# File c:\users\brady\appdata\local\programs\python\python39\lib\site-packages\matplotlib\axes\_axes.py:711, in Axes.annotate(self, text, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#     706 @_docstring.dedent_interpd
#     707 def annotate(self, text, xy, xytext=None, xycoords='data', textcoords=None,
#     708              arrowprops=None, annotation_clip=None, **kwargs):
#     709     # Signature must match Annotation. This is verified in
#     710     # test_annotate_signature().
# --> 711     a = mtext.Annotation(text, xy, xytext=xytext, xycoords=xycoords,
#     712                          textcoords=textcoords, arrowprops=arrowprops,
#     713                          annotation_clip=annotation_clip, **kwargs)
#     714     a.set_transform(mtransforms.IdentityTransform())
#     715     if kwargs.get('clip_on', False) and a.get_clip_path() is None:
#
# File c:\users\brady\appdata\local\programs\python\python39\lib\site-packages\matplotlib\text.py:1805, in Annotation.__init__(self, text, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#    1633 def __init__(self, text, xy,
#    1634              xytext=None,
#    1635              xycoords='data',
#    (...)
#    1638              annotation_clip=None,
#    1639              **kwargs):
#    1640     """
#    1641     Annotate the point *xy* with text *text*.
#    1642
#    (...)
#    1803
#    1804     """
# -> 1805     _AnnotationBase.__init__(self,
#    1806                              xy,
#    1807                              xycoords=xycoords,
#    1808                              annotation_clip=annotation_clip)
#    1809     # warn about wonky input data
#    1810     if (xytext is None and
#    1811             textcoords is not None and
#    1812             textcoords != xycoords):
#
# File c:\users\brady\appdata\local\programs\python\python39\lib\site-packages\matplotlib\text.py:1450, in _AnnotationBase.__init__(self, xy, xycoords, annotation_clip)
#    1445 def __init__(self,
#    1446              xy,
#    1447              xycoords='data',
#    1448              annotation_clip=None):
# -> 1450     x, y = xy  # Make copy when xy is an array (and check the shape).
#    1451     self.xy = x, y
#    1452     self.xycoords = xycoords
#
# TypeError: cannot unpack non-iterable numpy.float64 object

# %%
inertias=[]
distortions=[]
for k in range (1,10):
    model=KMeans(n_clusters=k).fit(X)
    distortion=cdist(X, model.cluster_centers_, 'euclidean')
    distortion=sum(np.min(distance, axis=1))/X.shape[0]
    distortions.append(distortion)

intertia=model.inertia_
intertias.append(inertia)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       4     model=KMeans(n_clusters=k).fit(X)
#       5     distortion=cdist(X, model.cluster_centers_, 'euclidean')
# ----> 6     distortion=sum(np.min(distance, axis=1))/X.shape[0]
#       7     distortions.append(distortion)
#       9 intertia=model.inertia_
#
# NameError: name 'distance' is not defined

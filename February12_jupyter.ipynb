# %%
import numpy as np
import pandas as pd

import math
import statistics
from scipy import stats

# %%
titanic_df=pd.read_csv('titanic_test_data.csv')

# %%
titanic_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
s_titanic_df=titanic_df['Embarked']=='S'

# %%
titanic_df[s_titanic_df]
# Out:
#      PassengerId  Pclass                                          Name  \
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                    Svensson, Mr. Johan Cervin
# 7            899       2                  Caldwell, Mr. Albert Francis
# ..           ...     ...                                           ...
# 409         1301       3                     Peacock, Miss. Treasteall
# 412         1304       3                Henriksson, Miss. Jenny Lovisa
# 413         1305       3                            Spector, Mr. Woolf
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
#
#         Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# ...

# %%
jep_data_df=pd.read_csv("JEOPARDY_DATA.csv")

# %%
jep_data_df
# Out:
#         Show Number    Air Date             Round  \
# 0              4680  12/31/2004         Jeopardy!
# 1              4680  12/31/2004         Jeopardy!
# 2              4680  12/31/2004         Jeopardy!
# 3              4680  12/31/2004         Jeopardy!
# 4              4680  12/31/2004         Jeopardy!
# ...             ...         ...               ...
# 216925         4999   5/11/2006  Double Jeopardy!
# 216926         4999   5/11/2006  Double Jeopardy!
# 216927         4999   5/11/2006  Double Jeopardy!
# 216928         4999   5/11/2006  Double Jeopardy!
# 216929         4999   5/11/2006   Final Jeopardy!
#
#                                Category    Value  \
# 0                               HISTORY    $200
# 1       ESPN's TOP 10 ALL-TIME ATHLETES    $200
# 2           EVERYBODY TALKS ABOUT IT...    $200
# 3                      THE COMPANY LINE    $200
# 4                   EPITAPHS & TRIBUTES    $200
# ...                                 ...      ...
# ...

# %%
jep_data_df.head()
# Out:
#    Show Number    Air Date      Round                         Category  Value  \
# 0         4680  12/31/2004  Jeopardy!                          HISTORY  $200
# 1         4680  12/31/2004  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2         4680  12/31/2004  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3         4680  12/31/2004  Jeopardy!                 THE COMPANY LINE  $200
# 4         4680  12/31/2004  Jeopardy!              EPITAPHS & TRIBUTES  $200
#
#                                             Question      Answer
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams

# %%
jep_data_df.columns
# Out:
# Index(['Show Number', ' Air Date', ' Round', ' Category', ' Value',
#        ' Question', ' Answer'],
#       dtype='object')

# %%
jep_data_df.columns=jep_data_df.columns.str.replace(' ', '')

# %%
jep_data_df.columns
# Out:
# Index(['ShowNumber', 'AirDate', 'Round', 'Category', 'Value', 'Question',
#        'Answer'],
#       dtype='object')

# %%
jep_data_df
# Out:
#         ShowNumber     AirDate             Round  \
# 0             4680  12/31/2004         Jeopardy!
# 1             4680  12/31/2004         Jeopardy!
# 2             4680  12/31/2004         Jeopardy!
# 3             4680  12/31/2004         Jeopardy!
# 4             4680  12/31/2004         Jeopardy!
# ...            ...         ...               ...
# 216925        4999   5/11/2006  Double Jeopardy!
# 216926        4999   5/11/2006  Double Jeopardy!
# 216927        4999   5/11/2006  Double Jeopardy!
# 216928        4999   5/11/2006  Double Jeopardy!
# 216929        4999   5/11/2006   Final Jeopardy!
#
#                                Category    Value  \
# 0                               HISTORY    $200
# 1       ESPN's TOP 10 ALL-TIME ATHLETES    $200
# 2           EVERYBODY TALKS ABOUT IT...    $200
# 3                      THE COMPANY LINE    $200
# 4                   EPITAPHS & TRIBUTES    $200
# ...                                 ...      ...
# ...

# %%
jep_data_df.dtypes
# Out:
# ShowNumber     int64
# AirDate       object
# Round         object
# Category      object
# Value         object
# Question      object
# Answer        object
# dtype: object

# %%
jep_data_df['AirDate']=pd.to_datetime(jep_data_df['AirDate'], format='%m/%d/%Y')
#preferable to sort by year-month-day though

# %%
jep_data_df.head()
# Out:
#    ShowNumber    AirDate      Round                         Category  Value  \
# 0        4680 2004-12-31  Jeopardy!                          HISTORY  $200
# 1        4680 2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2        4680 2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3        4680 2004-12-31  Jeopardy!                 THE COMPANY LINE  $200
# 4        4680 2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES  $200
#
#                                             Question      Answer
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams

# %%
# assign is used to assign a new column
jep_data_df=jep_data_df.assign(month=lambda x : x['AirDate'].dt.month)
jep_data_df.head()
# Out:
#    ShowNumber    AirDate      Round                         Category  Value  \
# 0        4680 2004-12-31  Jeopardy!                          HISTORY  $200
# 1        4680 2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2        4680 2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3        4680 2004-12-31  Jeopardy!                 THE COMPANY LINE  $200
# 4        4680 2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES  $200
#
#                                             Question      Answer  month
# 0  For the last 8 years of his life, Galileo was ...  Copernicus     12
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe     12
# 2  The city of Yuma in this state has a record av...     Arizona     12
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's     12
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams     12

# %%
jep_data_df['month2']=jep_data_df.apply(lambda x:x['AirDate'].month, axis=1)
jep_data_df.head()
# Out:
#    ShowNumber    AirDate      Round                         Category  Value  \
# 0        4680 2004-12-31  Jeopardy!                          HISTORY  $200
# 1        4680 2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2        4680 2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3        4680 2004-12-31  Jeopardy!                 THE COMPANY LINE  $200
# 4        4680 2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES  $200
#
#                                             Question      Answer  month  \
# 0  For the last 8 years of his life, Galileo was ...  Copernicus     12
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe     12
# 2  The city of Yuma in this state has a record av...     Arizona     12
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's     12
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams     12
#
#    month2
# 0      12
# 1      12
# 2      12
# 3      12
# 4      12

# %%
value_list=jep_data_df['Value'].tolist()
value_list=value_list[0:50]
value_list
# Out:
# ['$200 ',
#  '$200 ',
#  '$200 ',
#  '$200 ',
#  '$200 ',
#  '$200 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$600 ',
#  '$600 ',
#  '$600 ',
#  '$600 ',
#  '$600 ',
#  '$600 ',
#  '$800 ',
#  '$800 ',
#  '$800 ',
#  '$800 ',
#  '$2,000 ',
#  '$800 ',
#  '$1,000 ',
#  '$1,000 ',
#  '$1,000 ',
#  '$1,000 ',
#  '$1,000 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$800 ',
#  '$800 ',
#  '$800 ',
#  '$800 ',
#  '$800 ',
#  '$1,200 ',
#  '$2,000 ',
#  '$1,200 ',
#  '$1,200 ',
#  '$1,200 ',
#  '$1,600 ',
#  '$1,600 ',
#  '$1,600 ',
#  '$1,600 ',
#  '$1,600 ']

# %%
#what if we want to work with this data but preserve original values
filtered_list=list(filter(lambda num: int(num.replace('$', '').replace(' ', '').replace(',', ''))>300,value_list))

# %%
filtered_list
# Out:
# ['$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$600 ',
#  '$600 ',
#  '$600 ',
#  '$600 ',
#  '$600 ',
#  '$600 ',
#  '$800 ',
#  '$800 ',
#  '$800 ',
#  '$800 ',
#  '$2,000 ',
#  '$800 ',
#  '$1,000 ',
#  '$1,000 ',
#  '$1,000 ',
#  '$1,000 ',
#  '$1,000 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$800 ',
#  '$800 ',
#  '$800 ',
#  '$800 ',
#  '$800 ',
#  '$1,200 ',
#  '$2,000 ',
#  '$1,200 ',
#  '$1,200 ',
#  '$1,200 ',
#  '$1,600 ',
#  '$1,600 ',
#  '$1,600 ',
#  '$1,600 ',
#  '$1,600 ']
